# %% [markdown]
# # Python Basics

# %%
a=3
type(a)
# Out:
# int

# %%
a="abc"
print(type(a))
# Out:
# <class 'str'>

# %%
a={'Hours':5,'Mins':33}
print(type(a))
print(a)
# Out:
# <class 'dict'>
# {'Hours': 5, 'Mins': 33}

# %%
a=dict(hours=5,mins=30)
print(type(a))
print(a)
# Out:
# <class 'dict'>
# {'hours': 5, 'mins': 30}

# %%
a=2+3j
print(type(a))
print(a)
# Out:
# <class 'complex'>
# (2+3j)

# %%
a=[1,1.2,'abc',2+3j,[4,5,6],7]
print(type(a))
print(a)
# Out:
# <class 'list'>
# [1, 1.2, 'abc', (2+3j), [4, 5, 6], 7]

# %%
a=list('123')
print(a)
# Out:
# ['1', '2', '3']

# %%
a=(1,2,3)
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %%
a=tuple('Dhruv')
print(a)
# Out:
# ('D', 'h', 'r', 'u', 'v')

# %%
a=2>3
print(type(a))
print(a)
# Out:
# <class 'bool'>
# False

# %%
a=None
print(type(a))
print(a)
# Out:
# <class 'NoneType'>
# None

# %%
a=10
print(isinstance(a,float))
# Out:
# False

# %%
a=5
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 a=5
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
a={1,2,3,4,5,5,6,6,7}
print(type(a))
print(a)
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5, 6, 7}

# %%
a=[1,2,3,4,5]
print(type(a))
print(a[1])
print(len(a))
print(a)
b="Hello"
print(b.upper())
print(b.lower())
# Out:
# <class 'list'>
# 2
# 5
# [1, 2, 3, 4, 5]
# HELLO
# hello

# %%
a=2
b=3
a if a>b else b
# Out:
# 3

# %%
a=int(input("enter="))
print(type(a))
p=a-5
q=a
r=a>10
p if r else q
# Out:
# enter= 15
# <class 'int'>
# 10

# %%
a=[1,2,3]
b="Dhruv"
print(2 in a)
print('r'in b)
# Out:
# True
# True

# %%
a=2
b=3
print(a is not b)
# Out:
# True

# %%
a=2
print(id(a))
# Out:
# 140709789995848

# %%
import random
print(random.random()+10)
print(random.choice([1,2,3]))
# Out:
# 10.428077206787563
# 3

# %%
a=(1,2,3,4,5,6,7,8,9)
print(a)
print(a[0:5:2])
print(a[::-2])
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)
# (1, 3, 5)
# (9, 7, 5, 3, 1)

# %%
a=int(input("enter="))
b=a/2
c=isinstance(b,int)
d=isinstance(b,float)
print("div" if c else "Not div")
# Out:
# enter= 23
# N div
